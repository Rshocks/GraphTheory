# %% [markdown]
# ## Sets
# ***

# %% [markdown]
# -- A set is a group of objects represnted as a unit, such can be made up of numbers, other sets & symbols such objects can be called elements. Sets are a very core idea to maths --

# %% [markdown]
# ![image.png](attachment:image.png)
# A table of symbols in sets

# %% [markdown]
# Example : S = {5,6,43,21} made up of elements 5,6,43,21

# %% [markdown]
# ![image.png](attachment:image.png)
# Sets are also used in Venn diagrams

# %% [markdown]
# ## Sequences & Tuples
# ***

# %% [markdown]
# -- A sequence of objects are a list of objects in some order. Different to a set in which order doesn't matter --

# %% [markdown]
# Example : 7,1,21 is written as 1,7,21 in sequence, however in a set will stay 7,1,21 or 21,7,1 as order doesn't matter

# %% [markdown]
# -- Finite sequences are often called tuples. 7, 21, 57 is a 3 tuple, 1,2 is also called a order pair/2 tuple --

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Functions
# ***

# %% [markdown]
# -- A function is a object which sets up an input output relationship, a fucntion takes in the input then produces an output. Every function with the same input will produce the same output. It is also called mapping --

# %% [markdown]
# Example : f(a) - (a being input value) = b - (b being output value)

# %% [markdown]
# -- Addition is a function the input being a ordered pair of numbers and the output being the sum 1+2=3 --

# %% [markdown]
# ![image.png](attachment:image.png)
# Mapping in functions

# %% [markdown]
# ## Relations
# ***

# %% [markdown]
# -- A property is a function whose range is true,false --

# %% [markdown]
# Example : let even be a true if the input is even & false if the input is a odd number, even(4) = true and even(5) = false

# %% [markdown]
# In Scissors–Paper–Stone, the two players simultaneously
# select a member of the set SCISSORS, PAPER, STONE and indicate their selections with hand signals. If the two selections are the same, the game starts over.
# If the selections differ, one player wins, according to the relation beats.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Graphs
# ***

# %% [markdown]
# -- Graph are a set of points with lines connecting to some of the points, of which points are sometimes called nodes or vertices, with the lines being called edges --

# %% [markdown]
# Example :
# ![image.png](attachment:image.png)
# A formal description of the graph above is ({0,1,2,3,4},{(0,1),(1,2),(2,3),(3,4),(4,0)})

# %% [markdown]
# -- A path in a graph is a sequence of vertices connected by edges e.g a simple path would be 0 - 1 above --

# %% [markdown]
# -- Directed graph has arrows not lines the number of arrows pointing FROM a node is the outdegree, number of arrows pointing TO a node is a indegree --

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## String & Languages
# ***

# %% [markdown]
# -- Strings are characters, different alphabet may define an application ascii being the one we in Ireland use a language is just a set of strings --

# %% [markdown]
# ## Boolean Logic
# ***

# %% [markdown]
# -- Boolean Logic is a maths system built around two values true and false or maybe even 1 & 0, can be used when there are only two possible answers such as yes or no questions --
